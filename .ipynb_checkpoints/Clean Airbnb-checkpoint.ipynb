# %%
import urllib.request
import gzip
import shutil
import pandas as pd
import requests
import zipfile
import tempfile
import geopandas as gpd
from geopandas import GeoDataFrame
from shapely.geometry import Point

# %%
AirbnbURL = "http://data.insideairbnb.com/united-states/ny/new-york-city/2021-11-02/data/listings.csv.gz"
urllib.request.urlretrieve(AirbnbURL, "listing.csv.gz")
with gzip.open('listing.csv.gz', 'rb') as f_in:
    with open('listing.csv', 'wb') as f_out:
        shutil.copyfileobj(f_in, f_out)
        
airbnb = pd.read_csv('listing.csv',low_memory=False)

# %%
airbnb.drop(['listing_url', 'scrape_id', 'last_scraped','neighborhood_overview', 'picture_url', 'host_url',
       'host_name', 'host_since',
       'host_response_time', 'host_acceptance_rate',
       'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
       'host_neighbourhood', 'host_listings_count',
       'host_total_listings_count', 'host_verifications',
       'host_has_profile_pic', 'host_identity_verified', 'bathrooms', 'beds', 'amenities',
       'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
       'maximum_minimum_nights', 'minimum_maximum_nights',
       'maximum_maximum_nights', 'minimum_nights_avg_ntm',
       'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
       'availability_30', 'availability_60', 'availability_90',
       'availability_365', 'calendar_last_scraped',
       'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
       'last_review', 'review_scores_accuracy',
       'review_scores_cleanliness', 'review_scores_checkin',
       'review_scores_communication', 'review_scores_location',
       'review_scores_value', 'license', 'instant_bookable',
       'calculated_host_listings_count',
       'calculated_host_listings_count_entire_homes',
       'calculated_host_listings_count_private_rooms',
       'calculated_host_listings_count_shared_rooms', 'reviews_per_month'], axis=1)
# Out:
#              id                                               name  \
# 0          2595                              Skylit Midtown Castle
# 1          3831  Whole flr w/private bdrm, bath & kitchen(pls r...
# 2          5121                                    BlissArtsSpace!
# 3          5136           Spacious Brooklyn Duplex, Patio + Garden
# 4          5178                   Large Furnished Room Near B'way
# ...         ...                                                ...
# 37708  53123149        Lovely Room in Bedford-Stuyvesant Apartment
# 37709  53123691          Unfurnished Room in West Harlem Apartment
# 37710  53123840    MASSIVE 8BR/8BTH Brooklyn Townhouse w/ Backyard
# 37711  53126354          Unfurnished Room in West Harlem Apartment
# 37712  53127631               Bright Room in West Harlem Apartment
#
#                                              description    host_id  \
# 0      Beautiful, spacious skylit studio in the heart...       2845
# 1      Enjoy 500 s.f. top floor in 1899 brownstone, w...       4869
# 2      <b>The space</b><br />HELLO EVERYONE AND THANK...       7356
# 3      We welcome you to stay in our lovely 2 br dupl...       7378
# 4      Please don’t expect the luxury here just a bas...       8967
# ...                                                  ...        ...
# 37708  $200/MONTHLY FLEXIBILITY FEE<br />Unsure of ho...  305240193
# 37709  $200/MONTHLY FLEXIBILITY FEE<br />Unsure of ho...  305240193
# 37710  Newly renovated townhouse in Bushwick, includi...   13603829
# 37711  $200/MONTHLY FLEXIBILITY FEE<br />Unsure of ho...  305240193
# 37712  $200/MONTHLY FLEXIBILITY FEE<br />Unsure of ho...  305240193
#
#                            host_location  \
# 0      New York, New York, United States
# 1      New York, New York, United States
# 2      New York, New York, United States
# 3      Brooklyn, New York, United States
# 4      New York, New York, United States
# ...                                  ...
# 37708  New York, New York, United States
# 37709  New York, New York, United States
# 37710  Brooklyn, New York, United States
# 37711  New York, New York, United States
# 37712  New York, New York, United States
#
#                                               host_about host_response_rate  \
# 0      A New Yorker since 2000! My passion is creatin...                35%
# 1      Laid-back Native New Yorker (formerly bi-coast...                21%
# 2       I am an artist(painter, filmmaker) and curato...               100%
# 3      Rebecca is an artist/designer, and Henoch is i...               100%
# 4      I used to work for a financial industry but no...               100%
# ...                                                  ...                ...
# 37708  If you're searching for a place of your own or...                97%
# 37709  If you're searching for a place of your own or...                97%
# 37710                    Traveler, Entrepreneur, Artist                 90%
# 37711  If you're searching for a place of your own or...                97%
# 37712  If you're searching for a place of your own or...                97%
#
#                            neighbourhood neighbourhood_cleansed  \
# 0                New York, United States                Midtown
# 1      Brooklyn, New York, United States     Bedford-Stuyvesant
# 2                                    NaN     Bedford-Stuyvesant
# 3                                    NaN            Sunset Park
# 4                New York, United States                Midtown
# ...                                  ...                    ...
# 37708                                NaN     Bedford-Stuyvesant
# 37709                                NaN        Upper West Side
# 37710                                NaN               Bushwick
# 37711                                NaN        Upper West Side
# 37712                                NaN        Upper West Side
#
#       neighbourhood_group_cleansed   latitude  longitude  \
# 0                        Manhattan  40.753560 -73.985590
# 1                         Brooklyn  40.684940 -73.957650
# 2                         Brooklyn  40.685350 -73.955120
# 3                         Brooklyn  40.662650 -73.994540
# 4                        Manhattan  40.764570 -73.983170
# ...                            ...        ...        ...
# 37708                     Brooklyn  40.682389 -73.955540
# 37709                    Manhattan  40.801062 -73.961581
# 37710                     Brooklyn  40.682358 -73.908384
# 37711                    Manhattan  40.800454 -73.963746
# 37712                    Manhattan  40.799822 -73.966022
#
#                      property_type        room_type  accommodates  \
# 0               Entire rental unit  Entire home/apt             1
# 1               Entire guest suite  Entire home/apt             3
# 2      Private room in rental unit     Private room             2
# 3               Entire rental unit  Entire home/apt             4
# 4      Private room in rental unit     Private room             2
# ...                            ...              ...           ...
# 37708  Private room in rental unit     Private room             1
# 37709  Private room in rental unit     Private room             1
# 37710             Entire townhouse  Entire home/apt             8
# 37711  Private room in rental unit     Private room             1
# 37712  Private room in rental unit     Private room             1
#
#        bathrooms_text  bedrooms    price  number_of_reviews  \
# 0              1 bath       NaN  $150.00                 48
# 1              1 bath       1.0   $73.00                408
# 2                 NaN       1.0   $60.00                 50
# 3           1.5 baths       2.0  $275.00                  2
# 4              1 bath       1.0   $68.00                505
# ...               ...       ...      ...                ...
# 37708  2 shared baths       1.0   $65.00                  0
# 37709   1 shared bath       1.0   $58.00                  0
# 37710       7.5 baths       8.0  $914.00                  0
# 37711   1 shared bath       1.0   $66.00                  0
# 37712   1 shared bath       1.0   $65.00                  0
#
#        review_scores_rating
# 0                      4.70
# 1                      4.46
# 2                      4.52
# 3                      5.00
# 4                      4.21
# ...                     ...
# 37708                   NaN
# 37709                   NaN
# 37710                   NaN
# 37711                   NaN
# 37712                   NaN
#
# [37713 rows x 20 columns]
